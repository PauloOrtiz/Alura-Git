# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')

# %%
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor M² Tipo Agregado
# 0   1700.0       500.0  60.0     42.50   Apartamento
# 1   7000.0         0.0   0.0     70.00          Casa
# 2    800.0       390.0  20.0     53.33   Apartamento
# 3    800.0       230.0   0.0     16.67   Apartamento
# 4   1300.0       301.0  17.0     26.00   Apartamento
# 5  22000.0         0.0   0.0     29.33          Casa
# 6   1000.0         0.0   0.0     15.38          Casa
# 7   1500.0       642.0  74.0     21.43   Apartamento
# 8   1500.0       455.0  14.0     16.67   Apartamento
# 9   2000.0       561.0  50.0     50.00   Apartamento

# %%
dados['Valor'].mean()
# Out:
# 5046.172821405663

# %%
dados.Bairro.unique()
# Out:
# array(['Copacabana', 'Jardim Botânico', 'Centro', 'Higienópolis',
#        'Cachambi', 'Barra da Tijuca', 'Ramos', 'Grajaú',
#        'Lins de Vasconcelos', 'Taquara', 'Freguesia (Jacarepaguá)',
#        'Tijuca', 'Olaria', 'Ipanema', 'Campo Grande', 'Botafogo',
#        'Recreio dos Bandeirantes', 'Leblon', 'Jardim Oceânico', 'Humaitá',
#        'Península', 'Méier', 'Vargem Pequena', 'Maracanã', 'Jacarepaguá',
#        'São Conrado', 'Vila Valqueire', 'Gávea', 'Cosme Velho',
#        'Bonsucesso', 'Todos os Santos', 'Laranjeiras', 'Itanhangá',
#        'Flamengo', 'Piedade', 'Lagoa', 'Catete', 'Jardim Carioca',
#        'Benfica', 'Glória', 'Praça Seca', 'Vila Isabel', 'Engenho Novo',
#        'Engenho de Dentro', 'Pilares', 'Água Santa', 'São Cristóvão',
#        'Ilha do Governador', 'Jardim Sulacap', 'Oswaldo Cruz',
#        'Vila da Penha', 'Anil', 'Vargem Grande', 'Tanque', 'Vaz Lobo',
#        'Madureira', 'São Francisco Xavier', 'Pechincha', 'Leme', 'Irajá',
#        'Quintino Bocaiúva', 'Urca', 'Penha', 'Gardênia Azul',
#        'Rio Comprido', 'Andaraí', 'Santa Teresa', 'Inhaúma',
#        'Marechal Hermes', 'Curicica', 'Santíssimo', 'Moneró', 'Camorim',
#        'Cascadura', 'Praia da Bandeira', 'Saúde', 'Joá', 'Realengo',
#        'Fátima', 'Inhoaíba', 'Rocha', 'Jardim Guanabara', 'Jabour',
#        'Braz de Pina', 'Praça da Bandeira', 'Vila Kosmos', 'Vista Alegre',
#        'Encantado', 'Campinho', 'Guaratiba', 'Riachuelo', 'Bangu', 'Lapa',
#        'Catumbi', 'Penha Circular', 'Abolição', 'Tomás Coelho', 'Colégio',
#        'Pavuna', 'Santa Cruz', 'Alto da Boa Vista', 'Cidade Nova',
#        'Bento Ribeiro', 'Estácio', 'Jardim América', 'Cordovil', 'Caju',
#        'Pedra de Guaratiba', 'Padre Miguel', 'Paciência', 'Del Castilho',
#        'Arpoador', 'Sampaio', 'Anchieta', 'Icaraí', 'Senador Vasconcelos',
#        'Rocha Miranda', 'Gamboa', 'Maria da Graça', 'Barra de Guaratiba',
#        'Vicente de Carvalho', 'Paquetá', 'Largo do Machado',
#        'Parada de Lucas', 'Freguesia (Ilha do Governador)', 'Portuguesa',
#        'Guadalupe', 'Parque Anchieta', 'Turiaçu', 'Pitangueiras',
#        'Vila Militar', 'Vidigal', 'Senador Camará', 'Usina',
#        'Vigário Geral', 'Cosmos', 'Jacaré', 'Cocotá', 'Honório Gurgel',
#        'Engenho da Rainha', 'Cachamorra', 'Zumbi', 'Tauá', 'Santo Cristo',
#        'Ribeira', 'Magalhães Bastos', 'Cacuia', 'Bancários', 'Cavalcanti',
#        'Rio da Prata', 'Cidade Jardim', 'Coelho Neto'], dtype=object)

# %%
bairros = ['Copacabana', 'Jardim Botânico', 'Centro', 'Higienópolis',
       'Cachambi', 'Barra da Tijuca', 'Ramos', 'Grajaú',
       'Lins de Vasconcelos', 'Taquara', 'Freguesia (Jacarepaguá)',
       'Tijuca', 'Olaria', 'Ipanema', 'Campo Grande', 'Botafogo',
       'Recreio dos Bandeirantes', 'Leblon', 'Jardim Oceânico', 'Humaitá',
       'Península', 'Méier', 'Vargem Pequena', 'Maracanã', 'Jacarepaguá',
       'São Conrado', 'Vila Valqueire', 'Gávea', 'Cosme Velho',
       'Bonsucesso', 'Todos os Santos', 'Laranjeiras', 'Itanhangá',
       'Flamengo', 'Piedade', 'Lagoa', 'Catete', 'Jardim Carioca',
       'Benfica', 'Glória', 'Praça Seca', 'Vila Isabel', 'Engenho Novo',
       'Engenho de Dentro', 'Pilares', 'Água Santa', 'São Cristóvão',
       'Ilha do Governador', 'Jardim Sulacap', 'Oswaldo Cruz',
       'Vila da Penha', 'Anil', 'Vargem Grande', 'Tanque', 'Vaz Lobo',
       'Madureira', 'São Francisco Xavier', 'Pechincha', 'Leme', 'Irajá',
       'Quintino Bocaiúva', 'Urca', 'Penha', 'Gardênia Azul',
       'Rio Comprido', 'Andaraí', 'Santa Teresa', 'Inhaúma',
       'Marechal Hermes', 'Curicica', 'Santíssimo', 'Moneró', 'Camorim',
       'Cascadura', 'Praia da Bandeira', 'Saúde', 'Joá', 'Realengo',
       'Fátima', 'Inhoaíba', 'Rocha', 'Jardim Guanabara', 'Jabour',
       'Braz de Pina', 'Praça da Bandeira', 'Vila Kosmos', 'Vista Alegre',
       'Encantado', 'Campinho', 'Guaratiba', 'Riachuelo', 'Bangu', 'Lapa',
       'Catumbi', 'Penha Circular', 'Abolição', 'Tomás Coelho', 'Colégio',
       'Pavuna', 'Santa Cruz', 'Alto da Boa Vista', 'Cidade Nova',
       'Bento Ribeiro', 'Estácio', 'Jardim América', 'Cordovil', 'Caju',
       'Pedra de Guaratiba', 'Padre Miguel', 'Paciência', 'Del Castilho',
       'Arpoador', 'Sampaio', 'Anchieta', 'Icaraí', 'Senador Vasconcelos',
       'Rocha Miranda', 'Gamboa', 'Maria da Graça', 'Barra de Guaratiba',
       'Vicente de Carvalho', 'Paquetá', 'Largo do Machado',
       'Parada de Lucas', 'Freguesia (Ilha do Governador)', 'Portuguesa',
       'Guadalupe', 'Parque Anchieta', 'Turiaçu', 'Pitangueiras',
       'Vila Militar', 'Vidigal', 'Senador Camará', 'Usina',
       'Vigário Geral', 'Cosmos', 'Jacaré', 'Cocotá', 'Honório Gurgel',
       'Engenho da Rainha', 'Cachamorra', 'Zumbi', 'Tauá', 'Santo Cristo',
       'Ribeira', 'Magalhães Bastos', 'Cacuia', 'Bancários', 'Cavalcanti',
       'Rio da Prata', 'Cidade Jardim', 'Coelho Neto']

# %%
dados['Bairro'].drop_duplicates()
# Out:
# 0             Copacabana
# 1        Jardim Botânico
# 2                 Centro
# 3           Higienópolis
# 4               Cachambi
#               ...
# 13855          Bancários
# 15277         Cavalcanti
# 15280       Rio da Prata
# 15412      Cidade Jardim
# 16428        Coelho Neto
# Name: Bairro, Length: 152, dtype: object

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor M² Tipo Agregado
# 0      1700.0       500.0  60.0     42.50   Apartamento
# 1      7000.0         0.0   0.0     70.00          Casa
# 2       800.0       390.0  20.0     53.33   Apartamento
# 3       800.0       230.0   0.0     16.67   Apartamento
# 4      1300.0       301.0  17.0     26.00   Apartamento
# ...       ...         ...   ...       ...           ...
# 21821   900.0       490.0  48.0     12.86   Apartamento
# 21822   800.0       350.0  25.0     29.63   Apartamento
# 21823  1800.0       800.0  40.0     23.08   Apartamento
# 21824  1400.0       509.0  37.0     29.17   Apartamento
# 21825  3000.0       760.0   0.0     42.86   Apartamento
#
# [21826 rows x 11 columns]

# %%
grupo_bairro = dados.groupby('Bairro')
grupo_bairro.groups
# Out:
# {'Abolição': [1553, 3184, 6655, 6951, 7634, 10138, 13165, 14187, 16054, 16639, 17139, 18797, 18805, 20106, 21387], 'Alto da Boa Vista': [2201, 12039, 12556, 13240, 13438, 14518], 'Anchieta': [3017, 8880, 15660, 17811], 'Andaraí': [384, 452, 514, 613, 790, 846, 854, 996, 1191, 1416, 1421, 1685, 1912, 2014, 2683, 3137, 3216, 3489, 3578, 3738, 3856, 4227, 4572, 4773, 4876, 4883, 4961, 5545, 5753, 5990, 6232, 6450, 6529, 6911, 7168, 7408, 7889, 7890, 8064, 8430, 9190, 9290, 9334, 9380, 9713, 9929, 10104, 10255, 10275, 10859, 10940, 10947, 11079, 11516, 11818, 12292, 12762, 13243, 13385, 13389, 13769, 13897, 13931, 13938, 14214, 14592, 14668, 15915, 16009, 16504, 16509, 16599, 16654, 17510, 17769, 17794, 17913, 18212, 18433, 18754, 18888, 18918, 19041, 19668, 19750, 19770, 20100, 20219, 20516, 20866, 21028, 21074, 21114, 21326, 21455, 21543, 21582], 'Anil': [241, 572, 604, 1227, 1632, 1664, 1789, 1932, 2127, 2378, 3586, 3675, 3860, 4153, 4369, 4651, 4769, 4790, 5261, 5340, 5660, 6130, 6150, 6329, 6367, 6483, 6598, 6870, 6923, 7044, 7058, 7430, 7522, 8100, 8153, 8791, 9499, 9631, 9930, 10162, 10321, 10576, 10631, 11953, 11960, 12478, 13189, 13396, 13398, 13415, 14063, 14376, 14528, 14873, 15512, 16581, 16660, 16761, 17527, 17804, 18189, 18323, 18523, 19452, 19556, 19707, 19778, 21131, 21251, 21663, 21717], 'Arpoador': [2775, 3015, 3185, 3350, 4527, 9531, 13867, 14115, 14816, 16538, 18475, 18675], 'Bancários': [13855, 14779, 15906, 20377], 'Bangu': [1292, 1684, 1703, 2133, 3863, 3956, 4080, 7364, 10490, 10528, 10542, 11205, 11424, 11515, 11862, 13479, 14602, 17877, 18182, 20479], 'Barra da Tijuca': [5, 14, 16, 21, 30, 32, 35, 42, 43, 60, 61, 64, 68, 74, 79, 93, 107, 110, 112, 117, 130, 132, 136, 150, 153, 155, 165, 166, 173, 186, 189, 207, 214, 221, 224, 233, 236, 239, 244, 259, 265, 274, 276, 291, 292, 293, 295, 302, 308, 311, 325, 335, 336, 345, 360, 366, 368, 374, 380, 387, 389, 400, 412, 432, 433, 435, 436, 439, 449, 451, 462, 463, 465, 473, 476, 484, 494, 500, 503, 511, 537, 538, 539, 540, 543, 547, 552, 554, 555, 556, 584, 587, 588, 590, 594, 596, 601, 611, 622, 630, ...], 'Barra de Guaratiba': [3676, 10098, 19495, 20876], 'Benfica': [100, 5724, 11274, 18264, 19201], 'Bento Ribeiro': [2250, 2951, 2984, 5173, 6008, 7440, 9878, 10183, 10949, 13094, 13457, 13624, 13761, 14179, 15796, 15837, 18395, 19026, 20159, 20901, 21371, 21633, 21793], 'Bonsucesso': [67, 264, 367, 714, 918, 1288, 1459, 1512, 2064, 2219, 2668, 2678, 3058, 3233, 3258, 4130, 4259, 4353, 4925, 5140, 5451, 5630, 6731, 6866, 7584, 7733, 7977, 8607, 9784, 9888, 10037, 10430, 11447, 11863, 12338, 12356, 12371, 12905, 12923, 14931, 14942, 14959, 15378, 15983, 16148, 16464, 16610, 16889, 16960, 17022, 17420, 17786, 18086, 18890, 18970, 18994, 19652, 20593, 20926], 'Botafogo': [23, 48, 87, 88, 111, 119, 127, 134, 196, 200, 225, 334, 362, 415, 416, 498, 524, 526, 545, 593, 649, 685, 719, 756, 765, 822, 827, 861, 915, 924, 928, 1006, 1043, 1080, 1091, 1110, 1116, 1127, 1140, 1165, 1201, 1205, 1223, 1250, 1282, 1295, 1304, 1317, 1348, 1383, 1414, 1419, 1455, 1517, 1529, 1579, 1630, 1655, 1670, 1699, 1741, 1742, 1788, 1814, 1823, 1826, 1853, 1922, 1931, 1957, 1972, 1981, 1989, 2029, 2066, 2069, 2081, 2083, 2084, 2088, 2097, 2148, 2149, 2165, 2179, 2197, 2242, 2247, 2297, 2352, 2381, 2396, 2413, 2431, 2433, 2470, 2509, 2519, 2532, 2580, ...], 'Braz de Pina': [873, 3995, 4290, 5975, 6812, 6845, 7242, 9121, 9292, 12051, 12242, 12994, 14164, 15111, 15726, 15893, 17658, 18230, 19599, 19655], 'Cachambi': [4, 56, 247, 252, 525, 629, 1389, 1683, 1862, 1949, 2087, 2178, 2556, 2633, 2889, 3009, 3045, 3080, 3755, 4060, 4161, 4195, 4204, 4398, 4446, 4635, 4638, 5272, 5280, 5292, 5308, 5455, 5523, 5572, 5749, 5862, 5919, 5987, 5996, 6173, 6176, 6239, 6378, 6386, 6485, 6600, 6771, 6832, 6850, 7315, 7423, 7441, 7625, 7737, 7907, 8014, 8046, 8066, 8200, 8217, 8600, 8685, 8896, 8904, 8944, 9119, 9123, 9232, 9476, 9578, 9582, 9682, 9855, 10187, 10194, 10353, 10783, 10813, 11075, 11090, 11356, ...

# %%
for bairro, data in grupo_bairro: 
    print('{} o valor medio deste bairro é R$ {}'.format(bairro, data.Valor.mean()))
# Out:
# Abolição o valor medio deste bairro é R$ 1195.3333333333333
# Alto da Boa Vista o valor medio deste bairro é R$ 3966.6666666666665
# Anchieta o valor medio deste bairro é R$ 875.0
# Andaraí o valor medio deste bairro é R$ 1464.7113402061855
# Anil o valor medio deste bairro é R$ 2048.8732394366198
# Arpoador o valor medio deste bairro é R$ 12923.916666666666
# Bancários o valor medio deste bairro é R$ 1825.0
# Bangu o valor medio deste bairro é R$ 1016.0
# Barra da Tijuca o valor medio deste bairro é R$ 7069.552938130986
# Barra de Guaratiba o valor medio deste bairro é R$ 5550.0
# Benfica o valor medio deste bairro é R$ 996.0
# Bento Ribeiro o valor medio deste bairro é R$ 1030.8695652173913
# Bonsucesso o valor medio deste bairro é R$ 1225.9322033898304
# Botafogo o valor medio deste bairro é R$ 8791.828178694159
# Braz de Pina o valor medio deste bairro é R$ 1115.0
# Cachambi o valor medio deste bairro é R$ 1157.1742424242425
# Cachamorra o valor medio deste bairro é R$ 3000.0
# Cacuia o valor medio deste bairro é R$ 916.6666666666666
# Caju o valor medio deste bairro é R$ 850.0
# Camorim o valor medio deste bairro é R$ 1735.2272727272727
# Campinho o valor medio deste bairro é R$ 1037.3333333333333
# Campo Grande o valor medio deste bairro é R$ 1267.71714922049
# Cascadura o valor medio deste bairro é R$ 948.7096774193549
# Catete o valor medio deste bairro é R$ 2267.0625
# Catumbi o valor medio deste bairro é R$ 1112.5
# Cavalcanti o valor medio deste bairro é R$ 595.0
# Centro o valor medio deste bairro é R$ 1254.7521865889212
# Cidade Jardim o valor medio deste bairro é R$ 12000.0
# Cidade Nova o valor medio deste bairro é R$ 1471.4285714285713
# Cocotá o valor medio deste bairro é R$ 1883.3333333333333
# Coelho Neto o valor medio deste bairro é R$ 700.0
# Colégio o valor medio deste bairro é R$ 885.0
# Copacabana o valor medio deste bairro é R$ 4126.677004538578
# Cordovil o valor medio deste bairro é R$ 905.5555555555555
# Cosme Velho o valor medio deste bairro é R$ 5343.548387096775
# Cosmos o valor medio deste bairro é R$ 658.3333333333334
# Curicica o valor medio deste bairro é R$ 1514.5657894736842
# Del Castilho o valor medio deste bairro é R$ 1261.304347826087
# Encantado o valor medio deste bairro é R$ 1050.0
# Engenho Novo o valor medio deste bairro é R$ 1035.8252427184466
# Engenho da Rainha o valor medio deste bairro é R$ 883.5714285714286
# Engenho de Dentro o valor medio deste bairro é R$ 1166.3513513513512
# Estácio o valor medio deste bairro é R$ 1233.9130434782608
# Flamengo o valor medio deste bairro é R$ 4113.526610644258
# Freguesia (Ilha do Governador) o valor medio deste bairro é R$ 1720.0
# Freguesia (Jacarepaguá) o valor medio deste bairro é R$ 4966.666666666667
# Fátima o valor medio deste bairro é R$ 956.6666666666666
# Gamboa o valor medio deste bairro é R$ 1116.6666666666667
# Gardênia Azul o valor medio deste bairro é R$ 761.1111111111111
# Glória o valor medio deste bairro é R$ 2467.2897196261683
# Grajaú o valor medio deste bairro é R$ 2038.6206896551723
# Guadalupe o valor medio deste bairro é R$ 700.0
# Guaratiba o valor medio deste bairro é R$ 1232.258064516129
# Gávea o valor medio deste bairro é R$ 6563.688372093024
# Higienópolis o valor medio deste bairro é R$ 1006.25
# Honório Gurgel o valor medio deste bairro é R$ 628.5714285714286
# Humaitá o valor medio deste bairro é R$ 3802.3101265822784
# Icaraí o valor medio deste bairro é R$ 2393.75
# Ilha do Governador o valor medio deste bairro é R$ 1728.0
# Inhaúma o valor medio deste bairro é R$ 821.4285714285714
# Inhoaíba o valor medio deste bairro é R$ 725.0
# Ipanema o valor medio deste bairro é R$ 9352.001133786847
# Irajá o valor medio deste bairro é R$ 1096.012658227848
# Itanhangá o valor medio deste bairro é R$ 9341.269841269841
# Jabour o valor medio deste bairro é R$ 723.3333333333334
# Jacarepaguá o valor medio deste bairro é R$ 2046.9877551020409
# Jacaré o valor medio deste bairro é R$ 1200.0
# Jardim América o valor medio deste bairro é R$ 714.2857142857143
# Jardim Botânico o valor medio deste bairro é R$ 8722.357414448668
# Jardim Carioca o valor medio deste bairro é R$ 2211.1111111111113
# Jardim Guanabara o valor medio deste bairro é R$ 2124.6875
# Jardim Oceânico o valor medio deste bairro é R$ 7626.086956521739
# Jardim Sulacap o valor medio deste bairro é R$ 1176.6666666666667
# Joá o valor medio deste bairro é R$ 16773.478260869564
# Lagoa o valor medio deste bairro é R$ 8147.075819672131
# Lapa o valor medio deste bairro é R$ 1488.7777777777778
# Laranjeiras o valor medio deste bairro é R$ 3555.2776470588237
# Largo do Machado o valor medio deste bairro é R$ 1880.0
# Leblon o valor medio deste bairro é R$ 8746.344992050874
# Leme o valor medio deste bairro é R$ 3944.759825327511
# Lins de Vasconcelos o valor medio deste bairro é R$ 1086.1702127659576
# Madureira o valor medio deste bairro é R$ 1017.6595744680851
# Magalhães Bastos o valor medio deste bairro é R$ 640.0
# Maracanã o valor medio deste bairro é R$ 1945.4961240310076
# Marechal Hermes o valor medio deste bairro é R$ 844.4444444444445
# Maria da Graça o valor medio deste bairro é R$ 1073.3333333333333
# Moneró o valor medio deste bairro é R$ 1900.0
# Méier o valor medio deste bairro é R$ 1355.8745098039215
# Olaria o valor medio deste bairro é R$ 1016.5625
# Oswaldo Cruz o valor medio deste bairro é R$ 823.8888888888889
# Paciência o valor medio deste bairro é R$ 580.0
# Padre Miguel o valor medio deste bairro é R$ 786.25
# Paquetá o valor medio deste bairro é R$ 10550.0
# Parada de Lucas o valor medio deste bairro é R$ 1062.5
# Parque Anchieta o valor medio deste bairro é R$ 1287.5
# Pavuna o valor medio deste bairro é R$ 648.9473684210526
# Pechincha o valor medio deste bairro é R$ 1357.4257425742574
# Pedra de Guaratiba o valor medio deste bairro é R$ 1082.1052631578948
# Penha o valor medio deste bairro é R$ 1023.3333333333334
# Penha Circular o valor medio deste bairro é R$ 1160.0
# Península o valor medio deste bairro é R$ 7061.538461538462
# Piedade o valor medio deste bairro é R$ 956.5384615384615
# Pilares o valor medio deste bairro é R$ 1077.5
# Pitangueiras o valor medio deste bairro é R$ 2725.0
# Portuguesa o valor medio deste bairro é R$ 1272.7272727272727
# Praia da Bandeira o valor medio deste bairro é R$ 1300.0
# Praça Seca o valor medio deste bairro é R$ 998.4146341463414
# Praça da Bandeira o valor medio deste bairro é R$ 1358.723404255319
# Quintino Bocaiúva o valor medio deste bairro é R$ 924.6666666666666
# Ramos o valor medio deste bairro é R$ 958.0
# Realengo o valor medio deste bairro é R$ 908.3333333333334
# Recreio dos Bandeirantes o valor medio deste bairro é R$ 3736.6130988477867
# Riachuelo o valor medio deste bairro é R$ 1143.9024390243903
# Ribeira o valor medio deste bairro é R$ 1420.0
# Rio Comprido o valor medio deste bairro é R$ 1610.240506329114
# Rio da Prata o valor medio deste bairro é R$ 1300.0
# Rocha o valor medio deste bairro é R$ 1086.842105263158
# Rocha Miranda o valor medio deste bairro é R$ 877.0
# Sampaio o valor medio deste bairro é R$ 937.5
# Santa Cruz o valor medio deste bairro é R$ 734.2857142857143
# Santa Teresa o valor medio deste bairro é R$ 2713.3333333333335
# Santo Cristo o valor medio deste bairro é R$ 1225.0
# Santíssimo o valor medio deste bairro é R$ 756.25
# Saúde o valor medio deste bairro é R$ 950.0
# Senador Camará o valor medio deste bairro é R$ 600.0
# Senador Vasconcelos o valor medio deste bairro é R$ 867.3529411764706
# São Conrado o valor medio deste bairro é R$ 8780.88803088803
# São Cristóvão o valor medio deste bairro é R$ 1391.71875
# São Francisco Xavier o valor medio deste bairro é R$ 1237.2413793103449
# Tanque o valor medio deste bairro é R$ 1335.7142857142858
# Taquara o valor medio deste bairro é R$ 1642.140350877193
# Tauá o valor medio deste bairro é R$ 1340.0
# Tijuca o valor medio deste bairro é R$ 2043.52
# Todos os Santos o valor medio deste bairro é R$ 1243.076923076923
# Tomás Coelho o valor medio deste bairro é R$ 737.0
# Turiaçu o valor medio deste bairro é R$ 700.0
# Urca o valor medio deste bairro é R$ 7925.958904109589
# Usina o valor medio deste bairro é R$ 1520.0
# Vargem Grande o valor medio deste bairro é R$ 3358.1666666666665
# Vargem Pequena o valor medio deste bairro é R$ 2703.480769230769
# Vaz Lobo o valor medio deste bairro é R$ 845.0
# Vicente de Carvalho o valor medio deste bairro é R$ 1075.7142857142858
# Vidigal o valor medio deste bairro é R$ 2600.0
# Vigário Geral o valor medio deste bairro é R$ 970.0
# Vila Isabel o valor medio deste bairro é R$ 1560.8333333333333
# Vila Kosmos o valor medio deste bairro é R$ 1311.8181818181818
# Vila Militar o valor medio deste bairro é R$ 500.0
# Vila Valqueire o valor medio deste bairro é R$ 1769.5833333333333
# Vila da Penha o valor medio deste bairro é R$ 1260.576923076923
# Vista Alegre o valor medio deste bairro é R$ 1114.375
# Zumbi o valor medio deste bairro é R$ 2150.0
# Água Santa o valor medio deste bairro é R$ 861.1111111111111

# %%
grupo_bairro['Valor', 'Condominio'].mean().round(2)
# Out:
# <ipython-input-50-1dd1f92bfee0>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grupo_bairro['Valor', 'Condominio'].mean().round(2)
#                      Valor  Condominio
# Bairro
# Abolição           1195.33      191.40
# Alto da Boa Vista  3966.67      885.00
# Anchieta            875.00       19.75
# Andaraí            1464.71      497.71
# Anil               2048.87      455.85
# ...                    ...         ...
# Vila Valqueire     1769.58      276.88
# Vila da Penha      1260.58      232.68
# Vista Alegre       1114.38      210.06
# Zumbi              2150.00     1050.00
# Água Santa          861.11      269.44
#
# [152 rows x 2 columns]

# %%
grupo_bairro2
# Out:
# Bairro
# Abolição             1195.33
# Alto da Boa Vista    3966.67
# Anchieta              875.00
# Andaraí              1464.71
# Anil                 2048.87
#                       ...
# Vila Valqueire       1769.58
# Vila da Penha        1260.58
# Vista Alegre         1114.38
# Zumbi                2150.00
# Água Santa            861.11
# Name: Valor, Length: 152, dtype: float64

# %% [markdown]
# ## Estatisticas Descritivas

# %%
grupo_bairro['Valor'].describe().round(2).head(10)
# Out:
#                      count      mean       std     min     25%     50%  \
# Bairro
# Abolição              15.0   1195.33    425.32   800.0   900.0  1180.0
# Alto da Boa Vista      6.0   3966.67   5513.59   600.0  1150.0  1725.0
# Anchieta               4.0    875.00    132.29   700.0   812.5   900.0
# Andaraí               97.0   1464.71    408.11   700.0  1200.0  1400.0
# Anil                  71.0   2048.87   1523.97   300.0  1100.0  1500.0
# Arpoador              12.0  12923.92   9064.21  4200.0  7325.0  8600.0
# Bancários              4.0   1825.00    665.21  1300.0  1525.0  1600.0
# Bangu                 20.0   1016.00    347.24   400.0   825.0   950.0
# Barra da Tijuca     3863.0   7069.55  11874.15   800.0  2500.0  4500.0
# Barra de Guaratiba     4.0   5550.00   2716.00  2200.0  3925.0  6000.0
#
#                          75%       max
# Bairro
# Abolição             1200.00    2300.0
# Alto da Boa Vista    3275.00   15000.0
# Anchieta              962.50    1000.0
# Andaraí              1650.00    2950.0
# Anil                 2675.00    7000.0
# Arpoador            16221.75   30000.0
# Bancários            1900.00    2800.0
# Bangu                1187.50    1650.0
# Barra da Tijuca      8500.00  600000.0
# Barra de Guaratiba   7625.00    8000.0

# %%
grupo_bairro['Valor'].aggregate(['min', 'max']).rename(columns = {'min': 'Mínimo','max':'Máximos'})
# Out:
#                    Mínimo  Máximos
# Bairro
# Abolição            800.0   2300.0
# Alto da Boa Vista   600.0  15000.0
# Anchieta            700.0   1000.0
# Andaraí             700.0   2950.0
# Anil                300.0   7000.0
# ...                   ...      ...
# Vila Valqueire      800.0  16000.0
# Vila da Penha       450.0   4500.0
# Vista Alegre        700.0   1400.0
# Zumbi              1600.0   2700.0
# Água Santa          600.0   1200.0
#
# [152 rows x 2 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (20, 10))

# %%
fig = grupo_bairro['Valor'].mean().plot.bar(color= 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por Bairro',{'fontsize':22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')

# %%
fig = grupo_bairro['Condominio'].mean().plot.bar(color= 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por Bairro',{'fontsize':22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')
